# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !pwd

# %% [markdown]
# # The dataset

# %%
data = pd.read_csv('Dinahar_P_properties/primary_data.csv',sep=';')
data
# Out:
#                  family               name class cap-diameter  cap-shape  \
# 0        Amanita Family         Fly Agaric     p     [10, 20]     [x, f]
# 1        Amanita Family        Panther Cap     p      [5, 10]     [p, x]
# 2        Amanita Family  False Panther Cap     p     [10, 15]     [x, f]
# 3        Amanita Family        The Blusher     e      [5, 15]     [x, f]
# 4        Amanita Family          Death Cap     p      [5, 12]     [x, f]
# ..                  ...                ...   ...          ...        ...
# 168   Saddle-Cup Family       White Saddle     p       [2, 6]        [o]
# 169       Bracket Fungi     Elfin's Saddle     p       [2, 4]        [o]
# 170       Bracket Fungi      Turban Fungus     p      [5, 15]        [o]
# 171        Morel Family       Common Morel     e       [3, 8]  [p, c, o]
# 172  Jelly Discs Family       Jelly Babies     p     [1, 1.5]  [x, f, s]
#
#     Cap-surface cap-color does-bruise-or-bleed gill-attachment gill-spacing  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   family                173 non-null    object
#  1   name                  173 non-null    object
#  2   class                 173 non-null    object
#  3   cap-diameter          173 non-null    object
#  4   cap-shape             173 non-null    object
#  5   Cap-surface           133 non-null    object
#  6   cap-color             173 non-null    object
#  7   does-bruise-or-bleed  173 non-null    object
#  8   gill-attachment       145 non-null    object
#  9   gill-spacing          102 non-null    object
#  10  gill-color            173 non-null    object
#  11  stem-height           173 non-null    object
#  12  stem-width            173 non-null    object
#  13  stem-root             27 non-null     object
#  14  stem-surface          65 non-null     object
# ...

# %%
data.shape
# Out:
# (173, 23)

# %%
data.describe()
# Out:
#                    family        name class cap-diameter cap-shape  \
# count                 173         173   173          173       173
# unique                 23         173     2           51        27
# top     Tricholoma Family  Fly Agaric     p       [2, 5]       [x]
# freq                   43           1    96           16        48
#
#        Cap-surface cap-color does-bruise-or-bleed gill-attachment  \
# count          133       173                  173             145
# unique          40        67                    2               8
# top            [y]       [n]                  [f]             [a]
# freq            14        38                  143              32
#
#        gill-spacing  ... stem-root stem-surface stem-color veil-type  \
# count           102  ...        27           65        173         9
# unique            3  ...         5           14         41         1
# top             [c]  ...       [s]          [s]        [w]       [u]
# ...

# %%
# Headers
data_keys = data.keys()
data_keys
# Out:
# Index(['family', 'name', 'class', 'cap-diameter', 'cap-shape', 'Cap-surface',
#        'cap-color', 'does-bruise-or-bleed', 'gill-attachment', 'gill-spacing',
#        'gill-color', 'stem-height', 'stem-width', 'stem-root', 'stem-surface',
#        'stem-color', 'veil-type', 'veil-color', 'has-ring', 'ring-type',
#        'Spore-print-color', 'habitat', 'season'],
#       dtype='object')

# %% [markdown]
# # Missing values

# %%
# Number of unique values in the dataframe
for i in data_keys:
    unique_values_count = data.nunique(dropna=True)
unique_values_count
# Out:
# family                   23
# name                    173
# class                     2
# cap-diameter             51
# cap-shape                27
# Cap-surface              40
# cap-color                67
# does-bruise-or-bleed      2
# gill-attachment           8
# gill-spacing              3
# gill-color               59
# stem-height              46
# stem-width               48
# stem-root                 5
# stem-surface             14
# stem-color               41
# veil-type                 1
# veil-color                7
# has-ring                  2
# ring-type                13
# Spore-print-color         8
# habitat                  21
# season                   10
# dtype: int64

# %%
# The unique values in the dataframe
uniqueValues_names_list = []
for i in data_keys:
    uniqueValues_names = data[i].unique()
    uniqueValues_names_list.append(uniqueValues_names)
uniqueValues_names_list
# Out:
# [array(['Amanita Family', 'Lepiota Family', 'Tricholoma Family',
#         'Wax Gill Family', 'Russula Family', 'Pluteus Family',
#         'Entoloma Family', 'Bolbitius Family', 'Stropharia Family',
#         'Cortinarius Family', 'Mushroom Family', 'Ink Cap Family',
#         'Bolete Family', 'Paxillus Family', 'Chanterelle Family',
#         'Oyster Mushroom Family', 'Crepidotus Family', 'Hydnum Family',
#         'Ear-Pick Family', 'Bracket Fungi', 'Saddle-Cup Family',
#         'Morel Family', 'Jelly Discs Family'], dtype=object),
#  array(['Fly Agaric', 'Panther Cap', 'False Panther Cap', 'The Blusher',
#         'Death Cap', 'False Death Cap', 'Destroying Angel',
#         'Tawny Grisette', 'Parasol Mushroom', 'Shaggy Parasol',
#         'Stinking Parasol', 'Saffron Parasol', 'The Deceiver',
#         'Amethyst Deceiver', 'Wood Blewit', 'Field Blewit',
#         'Clouded Agaric', 'Club-footed Funnel Cap', 'Common Funnel Cap',
# ...

# %% [markdown]
# Apart from NAN there are no weird values in the dataset

# %%
# Missing NAN values %
data.isnull().sum().sort_values(ascending=False)*100/len(data)
# Out:
# veil-type               94.797688
# Spore-print-color       89.595376
# veil-color              87.861272
# stem-root               84.393064
# stem-surface            62.427746
# gill-spacing            41.040462
# Cap-surface             23.121387
# gill-attachment         16.184971
# ring-type                4.046243
# family                   0.000000
# habitat                  0.000000
# has-ring                 0.000000
# stem-color               0.000000
# stem-height              0.000000
# stem-width               0.000000
# name                     0.000000
# gill-color               0.000000
# does-bruise-or-bleed     0.000000
# cap-color                0.000000
# cap-shape                0.000000
# cap-diameter             0.000000
# class                    0.000000
# season                   0.000000
# dtype: float64

# %%
# just checking the meaning of the NAN values for each column that has NAN values
# data[data['family'] == 'Bolete Family']
data[data['family'] == 'Amanita Family']
# Out:
#            family               name class cap-diameter cap-shape Cap-surface  \
# 0  Amanita Family         Fly Agaric     p     [10, 20]    [x, f]      [g, h]
# 1  Amanita Family        Panther Cap     p      [5, 10]    [p, x]         [g]
# 2  Amanita Family  False Panther Cap     p     [10, 15]    [x, f]         NaN
# 3  Amanita Family        The Blusher     e      [5, 15]    [x, f]         NaN
# 4  Amanita Family          Death Cap     p      [5, 12]    [x, f]         [h]
# 5  Amanita Family    False Death Cap     e       [4, 9]       [x]         NaN
# 6  Amanita Family   Destroying Angel     p      [5, 10]       [b]         [t]
# 7  Amanita Family     Tawny Grisette     e       [4, 8]    [c, x]      [h, t]
#
#   cap-color does-bruise-or-bleed gill-attachment gill-spacing  ... stem-root  \
# 0    [e, o]                  [f]             [e]          NaN  ...       [s]
# 1       [n]                  [f]             [e]          NaN  ...       NaN
# ...

# %% [markdown]
# Veil-type: The NAN values in the veil-type feature represents the absence of veil. Replace NAN with a letter <br />
# veil-color: Replace NAN with a letter <br />
# Spore-print-color: Drop it <br />
# stem-surface: ????  <br />
# gill-spacing: ????  <br />
# Cap-surface, gill-attachment, ring-type: replace NAN with mean or most-frequent

# %% [markdown]
# # Duplicates

# %%
# Sum-up the duplicates for each column
duplicated_rows = data[data.duplicated()]
duplicated_rows
# Out:
# Empty DataFrame
# Columns: [family, name, class, cap-diameter, cap-shape, Cap-surface, cap-color, does-bruise-or-bleed, gill-attachment, gill-spacing, gill-color, stem-height, stem-width, stem-root, stem-surface, stem-color, veil-type, veil-color, has-ring, ring-type, Spore-print-color, habitat, season]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# There are no duplicated records in the dataset.

# %% [markdown]
# # Is the target balanced?

# %%
sns.histplot(data['class'])
# Out:
# <AxesSubplot:xlabel='class', ylabel='Count'>

# %%
data['class'].value_counts()
# Out:
# p    96
# e    77
# Name: class, dtype: int64

# %% [markdown]
# # Distribution of values (features)

# %%
sea = sns.histplot(data.iloc[:,3], kde=True)
sea.set(xticklabels=[])
sea.set(yticklabels=[])
# Out:
# [[Text(0, 0.0, ''),
#   Text(0, 2.0, ''),
#   Text(0, 4.0, ''),
#   Text(0, 6.0, ''),
#   Text(0, 8.0, ''),
#   Text(0, 10.0, ''),
#   Text(0, 12.0, ''),
#   Text(0, 14.0, ''),
#   Text(0, 16.0, ''),
#   Text(0, 18.0, '')]]

# %% [markdown]
# # Pipeline

# %%
from sklearn import set_config; set_config(display='diagram')
from sklearn.preprocessing import MinMaxScaler, StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer, make_column_transformer, make_column_selector

# %% [markdown]
# ## Prepossessing pipeline

# %%
# Define X and y
X = data.drop(columns=['family','name','class','Spore-print-color'])
y = data['class']

# %%
X.shape, y.shape
# Out:
# ((173, 20), (173,))

# %%
# onehotencoder
#simple imputer

# %% [markdown]
# ## Model pipeline
